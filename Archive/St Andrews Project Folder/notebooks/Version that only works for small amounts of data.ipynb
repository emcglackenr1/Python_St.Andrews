# %% [markdown]
# # Python for data analysis and visualisation
#
# ## Online short course at the University of St Andrews
#
# ## Final assignment
#
# ### Emma McGlacken Ryan

# %%
import pandas as pd

# %% [markdown]
# We start with exploring the content of the dataset.

# %%
df = pd.read_csv("../data/Scotland_teaching_file_1PCT.csv")

# %%
df
# Out:
#        Record_Number     Region RESIDENCE_TYPE Family_Composition  sex  age  \
# 0                  1  S92000003              P                  1    1    4
# 1                  2  S92000003              P                  0    1    3
# 2                  3  S92000003              P                  1    2    4
# 3                  4  S92000003              P                  1    2    6
# 4                  5  S92000003              P                  4    2    4
# ...              ...        ...            ...                ...  ...  ...
# 63383          63384  S92000003              P                  1    1    2
# 63384          63385  S92000003              P                  1    1    4
# 63385          63386  S92000003              P                  1    1    5
# 63386          63387  S92000003              P                  4    2    1
# 63387          63388  S92000003              P                  1    1    5
#
#        Marital_Status  student  Country_Of_Birth  health  Ethnic_Group  \
# 0                   2        2                 2       2             1
# 1                   1        2                 1       2             1
# 2                   2        2                 1       3             1
# 3                   2        2                 1       1             1
# 4                   4        2                 1       2             1
# ...               ...      ...               ...     ...           ...
# 63383               1        1                 1       1             1
# 63384               2        2                 1       1             1
# 63385               2        2                 1       1             1
# 63386               1        1                 1       1             1
# 63387               2        2                 1       2             1
#
#        religion Economic_Activity Occupation industry Hours_Worked_Per_Week  \
# 0             5                 1          5        5                     4
# 1             1                 1          1        8                     3
# 2             1                 1          4        8                     2
# 3             1                 1          2        8                     4
# 4             1                 1          3       11                     3
# ...         ...               ...        ...      ...                   ...
# 63383         2                 6          X        X                     X
# 63384         1                 1          3        9                     3
# 63385         9                 1          8        3                     4
# 63386         9                 X          X        X                     X
# 63387         2                 2          8        2                     4
#
#       Approximate_Social_Grade
# 0                            3
# 1                            2
# 2                            4
# 3                            2
# 4                            2
# ...                        ...
# 63383                        3
# 63384                        2
# 63385                        4
# 63386                        X
# 63387                        4
#
# [63388 rows x 17 columns]

# %% [markdown]
# ## Reading the data types of the columns

# %% [markdown]
# pd.read_csv("../data/Scotland_teaching_file_1PCT.csv").dtypes

# %% [markdown]
# ## Determining Unique Values

# %% [markdown]
# ### Getting list of columns

# %%
get_col = list(pd.read_csv("../data/Scotland_teaching_file_1PCT.csv",nrows=1).columns)
print(get_col)
# Out:
# ['Record_Number', 'Region', 'RESIDENCE_TYPE', 'Family_Composition', 'sex', 'age', 'Marital_Status', 'student', 'Country_Of_Birth', 'health', 'Ethnic_Group', 'religion', 'Economic_Activity', 'Occupation', 'industry', 'Hours_Worked_Per_Week', 'Approximate_Social_Grade']

# %% [markdown]
# ### Separate the column headings from the rest of the data, in order to help with duplicate identification
# Everything has a unique response code so, duplicates won't have a 'Unique reference ID', so duplicate responses will have different IDs, but have the same responese. I therefore removed Record_Number from the columns to be analysed.

# %%
responses = pd.read_csv("../data/Scotland_teaching_file_1PCT.csv", skiprows=1)

# %%
print(responses)
# Out:
#            1  S92000003  P 1.1  1.2  4  2  2.1  2.2  2.3  1.3  5 1.4 5.1 5.2  \
# 0          2  S92000003  P   0    1  3  1    2    1    2    1  1   1   1   8
# 1          3  S92000003  P   1    2  4  2    2    1    3    1  1   1   4   8
# 2          4  S92000003  P   1    2  6  2    2    1    1    1  1   1   2   8
# 3          5  S92000003  P   4    2  4  4    2    1    2    1  1   1   3  11
# 4          6  S92000003  P   1    1  5  2    2    1    1    1  1   1   3   9
# ...      ...        ... ..  ..  ... .. ..  ...  ...  ...  ... ..  ..  ..  ..
# 63382  63384  S92000003  P   1    1  2  1    1    1    1    1  2   6   X   X
# 63383  63385  S92000003  P   1    1  4  2    2    1    1    1  1   1   3   9
# 63384  63386  S92000003  P   1    1  5  2    2    1    1    1  9   1   8   3
# 63385  63387  S92000003  P   4    2  1  1    1    1    1    1  9   X   X   X
# 63386  63388  S92000003  P   1    1  5  2    2    1    2    1  2   2   8   2
#
#       4.1  3
# 0       3  2
# 1       2  4
# 2       4  2
# 3       3  2
# 4       3  2
# ...    .. ..
# 63382   X  3
# 63383   3  2
# 63384   4  4
# 63385   X  X
# 63386   4  4
#
# [63387 rows x 17 columns]

# %%
df = pd.DataFrame(responses,
                  columns=['Region', 'RESIDENCE_TYPE', 'Family_Composition', 'sex', 'age', 'Marital_Status', 'student', 'Country_Of_Birth', 'health', 'Ethnic_Group', 'religion', 'Economic_Activity', 'Occupation', 'industry', 'Hours_Worked_Per_Week', 'Approximate_Social_Grade'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.DataFrame(responses,
#       2                   columns=['Region', 'RESIDENCE_TYPE', 'Family_Composition', 'sex', 'age', 'Marital_Status', 'student', 'Country_Of_Birth', 'health', 'Ethnic_Group', 'religion', 'Economic_Activity', 'Occupation', 'industry', 'Hours_Worked_Per_Week', 'Approximate_Social_Grade'])
#
# NameError: name 'pd' is not defined

# %%
duplicate = df.duplicated

# %%
duplicate = df[df.duplicated(keep='last')]
 
print("Duplicate Rows :")
duplicate
# Out:
# Duplicate Rows :
#        Region  RESIDENCE_TYPE  Family_Composition  sex  age  Marital_Status  \
# 0         NaN             NaN                 NaN  NaN  NaN             NaN
# 1         NaN             NaN                 NaN  NaN  NaN             NaN
# 2         NaN             NaN                 NaN  NaN  NaN             NaN
# 3         NaN             NaN                 NaN  NaN  NaN             NaN
# 4         NaN             NaN                 NaN  NaN  NaN             NaN
# ...       ...             ...                 ...  ...  ...             ...
# 63381     NaN             NaN                 NaN  NaN  NaN             NaN
# 63382     NaN             NaN                 NaN  NaN  NaN             NaN
# 63383     NaN             NaN                 NaN  NaN  NaN             NaN
# 63384     NaN             NaN                 NaN  NaN  NaN             NaN
# 63385     NaN             NaN                 NaN  NaN  NaN             NaN
#
#        student  Country_Of_Birth  health  Ethnic_Group  religion  \
# 0          NaN               NaN     NaN           NaN       NaN
# 1          NaN               NaN     NaN           NaN       NaN
# 2          NaN               NaN     NaN           NaN       NaN
# 3          NaN               NaN     NaN           NaN       NaN
# 4          NaN               NaN     NaN           NaN       NaN
# ...        ...               ...     ...           ...       ...
# 63381      NaN               NaN     NaN           NaN       NaN
# 63382      NaN               NaN     NaN           NaN       NaN
# 63383      NaN               NaN     NaN           NaN       NaN
# 63384      NaN               NaN     NaN           NaN       NaN
# 63385      NaN               NaN     NaN           NaN       NaN
#
#        Economic_Activity  Occupation  industry  Hours_Worked_Per_Week  \
# 0                    NaN         NaN       NaN                    NaN
# 1                    NaN         NaN       NaN                    NaN
# 2                    NaN         NaN       NaN                    NaN
# 3                    NaN         NaN       NaN                    NaN
# 4                    NaN         NaN       NaN                    NaN
# ...                  ...         ...       ...                    ...
# 63381                NaN         NaN       NaN                    NaN
# 63382                NaN         NaN       NaN                    NaN
# 63383                NaN         NaN       NaN                    NaN
# 63384                NaN         NaN       NaN                    NaN
# 63385                NaN         NaN       NaN                    NaN
#
#        Approximate_Social_Grade
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 63381                       NaN
# 63382                       NaN
# 63383                       NaN
# 63384                       NaN
# 63385                       NaN
#
# [63386 rows x 16 columns]

# %%
print(df.duplicated(keep='last').sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(df.duplicated(keep='last').sum())
#
# NameError: name 'df' is not defined
