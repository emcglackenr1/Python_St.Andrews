# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
from causalinference import CausalModel

# %%
df = pd.read_csv('project_data.csv')
df = df.iloc[:, 1 : ]
df.head()
# Out:
#       Region RESIDENCE_TYPE Family_Composition  sex  age  Marital_Status  \
# 0  S92000003              P                  1    1    4               2
# 1  S92000003              P                  0    1    3               1
# 2  S92000003              P                  1    2    4               2
# 3  S92000003              P                  1    2    6               2
# 4  S92000003              P                  4    2    4               4
#
#    student  Country_Of_Birth  health  Ethnic_Group  religion  \
# 0        2                 2       2             1         5
# 1        2                 1       2             1         1
# 2        2                 1       3             1         1
# 3        2                 1       1             1         1
# 4        2                 1       2             1         1
#
#   Economic_Activity Occupation industry Hours_Worked_Per_Week  \
# 0                 1          5        5                     4
# ...

# %% [markdown]
# ## Step 1: Read the csv file into a DataFrame

# %%
file_path = 'project_data.csv'
df = pd.read_csv(file_path)

# %%
print(df)
# Out:
#        Record_Number     Region RESIDENCE_TYPE Family_Composition  sex  age  \
# 0                  1  S92000003              P                  1    1    4
# 1                  2  S92000003              P                  0    1    3
# 2                  3  S92000003              P                  1    2    4
# 3                  4  S92000003              P                  1    2    6
# 4                  5  S92000003              P                  4    2    4
# ...              ...        ...            ...                ...  ...  ...
# 63383          63384  S92000003              P                  1    1    2
# 63384          63385  S92000003              P                  1    1    4
# 63385          63386  S92000003              P                  1    1    5
# 63386          63387  S92000003              P                  4    2    1
# 63387          63388  S92000003              P                  1    1    5
#
# ...

# %% [markdown]
# ## Sidenote
# ### Determine max display rows (just out of curiosity)
# use pd.options.display.max_rows answer was 60
#
# Asked it to increase to 9999
# Not sure it achieved much.

# %%
import pandas as pd

pd.options.display.max_rows = 9999

df = pd.read_csv('project_data.csv')

print(df)
# Out:
#        Record_Number     Region RESIDENCE_TYPE Family_Composition  sex  age  \
# 0                  1  S92000003              P                  1    1    4
# 1                  2  S92000003              P                  0    1    3
# 2                  3  S92000003              P                  1    2    4
# 3                  4  S92000003              P                  1    2    6
# 4                  5  S92000003              P                  4    2    4
# ...              ...        ...            ...                ...  ...  ...
# 63383          63384  S92000003              P                  1    1    2
# 63384          63385  S92000003              P                  1    1    4
# 63385          63386  S92000003              P                  1    1    5
# 63386          63387  S92000003              P                  4    2    1
# 63387          63388  S92000003              P                  1    1    5
#
# ...

# %%
column_name = 'Family_Composition'

duplicate_values = df[column_name].duplicated()

# %%
print(duplicate_values)
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 63383     True
# 63384     True
# 63385     True
# 63386     True
# 63387     True
# Name: Family_Composition, Length: 63388, dtype: bool

# %% [markdown]
# https://www.linkedin.com/pulse/data-analytics-tutorial-python-perform-duplicate-check-nasierkhan
